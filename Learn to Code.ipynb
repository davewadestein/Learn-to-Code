# %% [markdown]
# # Who Am I?
# * 30+ years teaching experience
#   * two universities
#   * high school (__what__ was I thinking?)
#   * 10 years teaching cilivian progammers/engineers for US Navy
#   * 10 years corporate training for DevelopIntelligence/Pluralsight

# %% [markdown]
# # Learn to Code: The Basics Explained Clearly
# * What is Coding/Programming?
#    * hold that thought...

# %% [markdown]
# # FAQs
# * Do I need any prior coding experience?
# * What programming language will we use?
# * Will I be able to follow along if I'm not technical?
# * Will this workshop teach me enough to become a programmer?
# * Will this be a lecture of hands-on?
# * What will I be able to do after today's session?
# * Is this a good fit for career changers?
# * Will the session be recorded?

# %% [markdown]
# # Some Coding Myths
# 1. You have to be great at math
# 2. Good programmers memorize syntax
# 3. Programming is mostly typing
# 4. Programming is a solitary activity
# 5. There’s one correct solution
# 6. You must learn everything at the beginning
# 7. Errors mean you’re bad at coding
# 8. AI will replace programmers

# %% [markdown]
# # What is Coding/Programming?

# %% [markdown]
# # Tip Jar
# * not expected at all, but people ask...
#   * https://buymeacoffee.com/instructor.dws
